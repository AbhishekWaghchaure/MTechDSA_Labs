# %%
import random

# Number of individuals in each generation
POPULATION_SIZE = 100

# Valid genes
GENES = '''abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOP
QRSTUVWXYZ 1234567890, .-;:_!"#%&/()=?@${[]}'''

# Target string to be generated
TARGET = "Complete SCT Practicals"

class Individual(object):
	'''
	Class representing individual in population
	'''
	def __init__(self, chromosome):
		self.chromosome = chromosome
		self.fitness = self.cal_fitness()

	@classmethod
	def mutated_genes(self):
		'''
		create random genes for mutation
		'''
		global GENES
		gene = random.choice(GENES)
		return gene

	@classmethod
	def create_gnome(self):
		'''
		create chromosome or string of genes
		'''
		global TARGET
		gnome_len = len(TARGET)
		return [self.mutated_genes() for _ in range(gnome_len)]

	def mate(self, par2):
		'''
		Perform mating and produce new offspring
		'''

		# chromosome for offspring
		child_chromosome = []
		for gp1, gp2 in zip(self.chromosome, par2.chromosome):

			# random probability
			prob = random.random()

			# if prob is less than 0.45, insert gene
			# from parent 1
			if prob < 0.45:
				child_chromosome.append(gp1)

			# if prob is between 0.45 and 0.90, insert
			# gene from parent 2
			elif prob < 0.90:
				child_chromosome.append(gp2)

			# otherwise insert random gene(mutate),
			# for maintaining diversity
			else:
				child_chromosome.append(self.mutated_genes())

		# create new Individual(offspring) using
		# generated chromosome for offspring
		return Individual(child_chromosome)

	def cal_fitness(self):
		'''
		Calculate fitness score, it is the number of
		characters in string which differ from target
		string.
		'''
		global TARGET
		fitness = 0
		for gs, gt in zip(self.chromosome, TARGET):
			if gs != gt: fitness+= 1
		return fitness

# Driver code
def main():
	global POPULATION_SIZE

	#current generation
	generation = 1

	found = False
	population = []

	# create initial population
	for _ in range(POPULATION_SIZE):
				gnome = Individual.create_gnome()
				population.append(Individual(gnome))

	while not found:

		# sort the population in increasing order of fitness score
		population = sorted(population, key = lambda x:x.fitness)

		# if the individual having lowest fitness score ie.
		# 0 then we know that we have reached to the target
		# and break the loop
		if population[0].fitness <= 0:
			found = True
			break

		# Otherwise generate new offsprings for new generation
		new_generation = []

		# Perform Elitism, that mean 10% of fittest population
		# goes to the next generation
		s = int((10*POPULATION_SIZE)/100)
		new_generation.extend(population[:s])

		# From 50% of fittest population, Individuals
		# will mate to produce offspring
		s = int((90*POPULATION_SIZE)/100)
		for _ in range(s):
			parent1 = random.choice(population[:50])
			parent2 = random.choice(population[:50])
			child = parent1.mate(parent2)
			new_generation.append(child)

		population = new_generation

		print("Generation: {}\tString: {}\tFitness: {}".\
			format(generation,
			"".join(population[0].chromosome),
			population[0].fitness))

		generation += 1


	print("Generation: {}\tString: {}\tFitness: {}".\
		format(generation,
		"".join(population[0].chromosome),
		population[0].fitness))

if __name__ == '__main__':
	main()
# Out:
# Generation: 1	String: Xbmcpz7tziy=dPZhVWcR/NQ	Fitness: 21
# Generation: 2	String: 4KRoniDLHACT;%B ONj)a5B	Fitness: 20
# Generation: 3	String: Xbm]Wz7J JC}kPuhVN7RTiB	Fitness: 19
# Generation: 4	String: Xbm]Wz7J JC}kPuhVN7RTiB	Fitness: 19
# Generation: 5	String: XFm!ezR$ iCs;PYhV iR05a	Fitness: 18
# Generation: 6	String: XFm!ezR$ iCs;PYhV iR05a	Fitness: 18
# Generation: 7	String: }bmcQzVJzVCI;PiOcNicK5_	Fitness: 17
# Generation: 8	String: Xwmp&z%H So}bPrh dic[53	Fitness: 15
# Generation: 9	String: ATmp&z%H So(bPrhcdic0F%	Fitness: 14
# Generation: 10	String: Abm:.zDe SCs=PrOcoicO3w	Fitness: 13
# Generation: 11	String: Abm:.zDe SCs=PrOcoicO3w	Fitness: 13
# Generation: 12	String: RKmpRK4e SCT"PrVc ]calt	Fitness: 10
# Generation: 13	String: RKmpRK4e SCT"PrVc ]calt	Fitness: 10
# Generation: 14	String: RKmpRK4e SCT"PrVc ]calt	Fitness: 10
# Generation: 15	String: RKmpRK4e SCT"PrVc ]calt	Fitness: 10
# Generation: 16	String: RKmpRK4e SCT"PrVc ]calt	Fitness: 10
# Generation: 17	String: RKmpRK4e SCT"PrVc ]calt	Fitness: 10
# Generation: 18	String: RbmpR{te SCf"PrVc#icalw	Fitness: 9
# Generation: 19	String: RbmpR{te SCf"PrVc#icalw	Fitness: 9
# Generation: 20	String: RbmpR{te SCf"PrVc#icalw	Fitness: 9
# Generation: 21	String: RbmpR{te SCf"PrVc#icalw	Fitness: 9
# Generation: 22	String: Rbmp@!t7 SCT PrCcqicalt	Fitness: 8
# Generation: 23	String: Rbmp@!t7 SCT PrCcqicalt	Fitness: 8
# Generation: 24	String: Rbmp@!t7 SCT PrCcqicalt	Fitness: 8
# Generation: 25	String: HKmpRste SCT PrVc#icalt	Fitness: 7
# Generation: 26	String: HKmpRste SCT PrVc#icalt	Fitness: 7
# Generation: 27	String: HKmpRste SCT PrVc#icalt	Fitness: 7
# Generation: 28	String: HKmpRste SCT PrVc#icalt	Fitness: 7
# Generation: 29	String: HKmpRste SCT PrVc#icalt	Fitness: 7
# Generation: 30	String: RAmpn!te SCT PrVcticalt	Fitness: 6
# Generation: 31	String: RAmpn!te SCT PrVcticalt	Fitness: 6
# Generation: 32	String: RAmpn!te SCT PrVcticalt	Fitness: 6
# Generation: 33	String: RAmpn!te SCT PrVcticalt	Fitness: 6
# Generation: 34	String: RAmpn!te SCT PrVcticalt	Fitness: 6
# Generation: 35	String: RAmpn!te SCT PrVcticalt	Fitness: 6
# Generation: 36	String: RAmpn!te SCT PrVcticalt	Fitness: 6
# Generation: 37	String: RAmpn!te SCT PrVcticalt	Fitness: 6
# Generation: 38	String: RAmpn!te SCT PrVcticalt	Fitness: 6
# Generation: 39	String: RAmpn!te SCT PrVcticalt	Fitness: 6
# Generation: 40	String: RAmpn!te SCT PrVcticalt	Fitness: 6
# Generation: 41	String: 7Bmpuste SCT Practical8	Fitness: 5
# Generation: 42	String: 7Bmpuste SCT Practical8	Fitness: 5
# Generation: 43	String: 7Bmpuste SCT Practical8	Fitness: 5
# Generation: 44	String: 7Bmpuste SCT Practical8	Fitness: 5
# Generation: 45	String: 7Bmpuste SCT Practical8	Fitness: 5
# Generation: 46	String: 7Bmpuste SCT Practical8	Fitness: 5
# Generation: 47	String: 7Bmpukte SCT Practicals	Fitness: 4
# Generation: 48	String: 7Bmpukte SCT Practicals	Fitness: 4
# Generation: 49	String: 7Bmpukte SCT Practicals	Fitness: 4
# Generation: 50	String: 7Bmpukte SCT Practicals	Fitness: 4
# Generation: 51	String: 7Bmpukte SCT Practicals	Fitness: 4
# Generation: 52	String: 7Bmpukte SCT Practicals	Fitness: 4
# Generation: 53	String: RompNkte SCT Practicals	Fitness: 3
# Generation: 54	String: RompNkte SCT Practicals	Fitness: 3
# Generation: 55	String: RompNkte SCT Practicals	Fitness: 3
# Generation: 56	String: RompNkte SCT Practicals	Fitness: 3
# Generation: 57	String: RompNkte SCT Practicals	Fitness: 3
# Generation: 58	String: RompNkte SCT Practicals	Fitness: 3
# Generation: 59	String: RompNkte SCT Practicals	Fitness: 3
# Generation: 60	String: RompNkte SCT Practicals	Fitness: 3
# Generation: 61	String: RompNkte SCT Practicals	Fitness: 3
# Generation: 62	String: RompNkte SCT Practicals	Fitness: 3
# Generation: 63	String: RompNkte SCT Practicals	Fitness: 3
# Generation: 64	String: RompNkte SCT Practicals	Fitness: 3
# Generation: 65	String: RompNkte SCT Practicals	Fitness: 3
# Generation: 66	String: RompNkte SCT Practicals	Fitness: 3
# Generation: 67	String: RompNkte SCT Practicals	Fitness: 3
# Generation: 68	String: RompNkte SCT Practicals	Fitness: 3
# Generation: 69	String: RompNkte SCT Practicals	Fitness: 3
# Generation: 70	String: RompNkte SCT Practicals	Fitness: 3
# Generation: 71	String: RompNkte SCT Practicals	Fitness: 3
# Generation: 72	String: RompNkte SCT Practicals	Fitness: 3
# Generation: 73	String: RompNkte SCT Practicals	Fitness: 3
# Generation: 74	String: Compbkte SCT Practicals	Fitness: 2
# Generation: 75	String: Compbkte SCT Practicals	Fitness: 2
# Generation: 76	String: Compbkte SCT Practicals	Fitness: 2
# Generation: 77	String: Compbkte SCT Practicals	Fitness: 2
# Generation: 78	String: Compbkte SCT Practicals	Fitness: 2
# Generation: 79	String: Compbkte SCT Practicals	Fitness: 2
# Generation: 80	String: Compbkte SCT Practicals	Fitness: 2
# Generation: 81	String: Compbkte SCT Practicals	Fitness: 2
# Generation: